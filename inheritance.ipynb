# %%
class Product:
    platform = 'AMAZON'

    def __init__(self, pid: int, title: str, price: float) -> None:
        self.pid = pid
        self.title = title
        self.price = price

    def __repr__(self) -> str:
        return f'Product(pid={self.pid}, title={self.title})'

# %%
class Seller:
    def __init__(self, sid: int, sname: str) -> None:
        self.sid = sid
        self.sname = sname

# %% [markdown]
# # Inheritance

# %%
class Cloth(Product): # derive class
  pass

# %%
c1 = Cloth(12, 'Shirt', 23.5)
c1
# Out:
# Product(pid=12, title=Shirt)

# %%
# Single Inheritance & Polymorphism - Compile and Runtime(Support)
class Cloth(Product):
    def __init__(self, pid: int, title: str, price: float, fabric: str) -> None:
        self.fabric = fabric
        super().__init__(pid, title, price)

    # Overriding it's parent's __repr__() method
    def __repr__(self) -> str:
        return f'Product(pid={self.pid}, title={self.title},price={self.price}, fabric={self.fabric})'

# %%
c1 = Cloth(2342, 'Tshirt', 399.0, 'Cotton')
c1
# Out:
# Product(pid=2342, title=Tshirt,price=399.0, fabric=Cotton)

# %%
Cloth.__mro__
Cloth.mro()

# %%
# Multilevel Inheritance
class TopWear(Cloth):
    def __init__(self, pid: int, title: str, price: float, fabric: str, wear_type:str) -> None:
        self.type = wear_type
        super().__init__(pid, title, price, fabric)

# %%
c1 = TopWear(243, 'Polo T-Shirt', 499.0, 'Cotton', 'TopWear')
c1
# Out:
# Product(pid=243, title=Polo T-Shirt,price=499.0, fabric=Cotton)

# %%
c1.type

# %%
# Multiple Inheritance
class Cloth(Product, Seller):
    def __init__(self, pid: int, title: str, price: float, sid: int, sname: str) -> None:
        Product.__init__(self, pid, title, price)
        Seller.__init__(self, sid, sname)

    def get(self):
        return Product.__repr__(self), Product.platform
    def __repr__(self) -> str:
        return f'Product(pid={self.pid}, title={self.title},price={self.price}, sid={self.sid}, sname={self.sname})'

# %%
c1 = Cloth(243, 'Polo T-Shirt', 499.0, 25, 'Tessa young')
c1

# %%
c1.get()

# %% [markdown]
# # Stopping Inhertitance

# %%
class Meta(type):
    def __new__(cls, name, bases, classdict):
        for base in bases:
            if isinstance(base, Meta):
                raise TypeError(f'Cannot Inherit class {base.__name__}')
            return type.__new__(cls, name, bases, classdict)

# %%
class Product:
    platform = 'AMAZON'

    def __init__(self, pid: int, title: str, price: float) -> None:
        self.pid = pid
        self.title = title
        self.price = price

    def __init_subclass__(cls, **kwargs) -> None:
        if cls is not Meta:
            raise TypeError(f'Cannot Inherit class {cls.__name__}')
        super().__init_subclass__(cls, **kwargs)

    def __repr__(self) -> str:
        return f'Product(pid={self.pid}, title={self.title})'

# %%
# Multiple Inheritance
class Cloth(Product):
    def __init__(self, pid: int, title: str, price: float) -> None:
        super().__init__(self, pid, title, price)

    def get(self):
        return Product.__repr__(self), Product.platform
    def __repr__(self) -> str:
        return f'Product(pid={self.pid}, title={self.title},price={self.price}, sid={self.sid}, sname={self.sname})'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\HRV\Professional\Machine-Learning\MLDS 1019\2_OOP\inheritance.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Multiple Inheritance
# ----> <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> class Cloth(Product):
#       <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a>     def __init__(self, pid: int, title: str, price: float) -> None:
#       <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>         super().__init__(self, pid, title, price)
#
# e:\HRV\Professional\Machine-Learning\MLDS 1019\2_OOP\inheritance.ipynb Cell 16 in Product.__init_subclass__(cls, **kwargs)
#       <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> def __init_subclass__(cls, **kwargs) -> None:
#      <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>     if cls is not Meta:
# ---> <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a>         raise TypeError(f'Cannot Inherit class {cls.__name__}')
#      <a href='vscode-notebook-cell:/e%3A/HRV/Professional/Machine-Learning/MLDS%201019/2_OOP/inheritance.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a>     super().__init_subclass__(cls, **kwargs)
#
# TypeError: Cannot Inherit class Cloth
